# %%
import psycopg2
import pandas as pd
import json

# %%
conn = psycopg2.connect(
    host= "proptechdb.cwrq9y4ax7rv.ap-south-1.rds.amazonaws.com",
    user= "postgres",
    password= "Postgres123",
    database= "proptech",
    port=5432
)
# Create a cursor
cursor = conn.cursor()

# %%
cur = conn.cursor()
cur.execute("SELECT version();")
record = cur.fetchone()
print("You are connected to - ", record,"\n")

# Code to show databases
cur.execute("SELECT datname FROM pg_database;")
databases = cur.fetchall()
print("Available databases:")
for db in databases:
    print(db[0])
# Out:
# You are connected to -  ('PostgreSQL 16.3 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 7.3.1 20180712 (Red Hat 7.3.1-12), 64-bit',)
#
# Available databases:
# template0
# template1
# postgres
# proptech
# rdsadmin
# recommendation_test

# %%
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public';")
tables = cur.fetchall()
print("\nAvailable tables:")
# print(tables)
for table in tables:
  print(table[0])
  # cur.execute("SELECT * FROM "+table[0]+";")
  # data.append(cur.fetchall())
# Out:
# Available tables:
# adminroles
# adminmenus
# kycdata
# subscriptions
# subscriptionhistories
# properties
# propertymedia
# users
# propertylocations
# propertydetails
# propertyamenities
# propertyverifications
# resettokens
# userprofiles
# mobileverifies
# favourites
# notifications
# shortlistedproperties
# propertyintrests
# hireagentorders
# bids
# lawyerleads
# contactpayments
# agentpayments
# bookings
# escrowamountrequests
# meetings
# proppaymentmethods
# bankerleads
# hirelawyerpayments
# assignlawyers
# buyerdocuments
# sellerdocuments
# propertyoffers
# propertysubscriptions
# bankdetails
# bankpannytransactions
# evaluatorpayments
# evaluatorescrowrequests
# Supportickets
# visitors
# agenttrainings
# agentexperiences
# propertypaymentschedules
# installmentwithdrawalrequests
# chats
# Agentpaymentreleaserequests

# %%
from itertools import chain
cur.execute(f"SELECT * FROM propertymedia order by id asc;")
data = cur.fetchall()

data1 = []  # Initialize data1 for each row
data2 = []  # Initialize data2 for each row
data3 = []  # Initialize data3 for each row

for row in data:
    # Extract only the 'image' column value
    images = row[1]  # Assuming 'image' is the column name
    floors=row[2]
    unitplans=row[3]
    data1.append(images)
    data2.append(floors)
    data3.append(unitplans)


# data1 = list(chain.from_iterable(data1))
# data2 = list(chain.from_iterable(data2))
# data3 = list(chain.from_iterable(data3))

# print(data1)
# print(data2)
# print(data3)

# for row in data:
#     # Extract only the 'image' column value
#     images = row['images']  # Assuming 'image' is the column name
#     data1.append(images)

# print(data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d404dc9356bf> in <cell line: 0>()
#       1 from itertools import chain
# ----> 2 cur.execute(f"SELECT * FROM propertymedia order by id asc;")
#       3 data = cur.fetchall()
#       4
#       5 data1 = []  # Initialize data1 for each row
#
# NameError: name 'cur' is not defined

# %%
# prompt: get data in dataframe with column name

import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host= "proptechdb.cwrq9y4ax7rv.ap-south-1.rds.amazonaws.com",
    user= "postgres",
    password= "Postgres123",
    database= "proptech",
    port=5432
)

# Create a cursor
cursor = conn.cursor()

# Execute the query and fetch results into a pandas DataFrame
query = "SELECT * FROM properties order by id asc;"
df = pd.read_sql_query(query, conn)
# print(df)
# Out:
# <ipython-input-13-1cfea5c1fdf8>:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
title_data = [
    "NextGen Realty Hub",
    "Smart Property Finder",
    "Dream Estate Explorer",
    "LandTrack Navigator",
    "Estate Insight Pro",
    "Property Scope",
    "Realty Visionary",
    "PropHunter AI",
    "Estate MapMaster",
    "HomeQuest Navigator",
    "RealtyGrid Solutions",
    "GeoProperty Insight",
    "LandView 360",
    "Estate Beacon",
    "DreamHome Locator",
    "UrbanEstate Mapper",
    "Estate Genius",
    "RealtyScout AI",
    "HomeSphere Navigator",
    "LandVision Pro",
    "Estate Connect",
    "GeoSmart Realty",
    "PropNav Explorer",
    "Dynamic Estate Mapper",
    "Estate360 Insight",
    "HomeMap Navigator",
    "Realty Explorer AI",
    "Property Finder Pro",
    "Estate Matrix",
    "SmartLand Navigator",
    "Property Locator 360",
    "DreamLand Tracker",
    "UrbanProp Insight",
    "Estate Axis",
    "LandSync Navigator",
    "GeoEstate Pro",
    "PropFinder AI",
    "Estate Beacon Lite",
    "HomeSeeker 360",
    "Landmark Explorer",
    "Property PathFinder",
    "DreamSpace Navigator",
    "Realty Advisor Pro",
    "SmartEstate Hub",
    "EstateGuide AI",
    "PropMap360",
    "GeoTrack Realty",
    "Estate Explorer Pro",
    "LandSpot Navigator",
    "DreamKey Navigator",
    "HomeVision Pro",
    "Realty Lens",
    "EstatePlanner AI",
    "LandTrail Insight",
    "PropSphere Navigator",
    "SmartEstate Advisor",
    "GeoHome Locator",
    "EstateHub Pro",
    "LandMaster 360",
    "UrbanKey Navigator",
    "EstateView AI",
    "PropExplorer Hub",
    "LandInsight Pro",
    "DreamMap 360",
    "GeoEstate Navigator",
    "Property Tracker AI",
    "Estate Link Hub",
    "LandVision AI",
    "EstateMaster 360",
    "PropLink Solutions",
    "GeoSpace Navigator",
    "DreamLocator Pro",
    "SmartKey Realty",
    "Estate Hunter AI",
    "LandMapper 360",
    "PropTrack Navigator",
    "DreamScope Explorer",
    "Realty Connect Pro",
    "SmartLand Explorer",
    "EstateMap AI",
    "GeoTrack Solutions",
    "DreamEstate Pro",
    "EstateInsight Lite",
    "UrbanMap Navigator",
    "PropertyLink Hub",
    "LandQuest Navigator",
    "Estate360 Pro",
    "SmartHome Navigator",
    "GeoKey Realty",
    "PropExplorer 360",
    "EstateSphere Pro",
    "LandSync AI",
    "UrbanNest Navigator",
    "EstateTrail Insight",
    "DreamLand AI",
    "PropertyNet 360",
    "RealtyWay Explorer",
    "LandFinder Navigator",
    "GeoEstate Advisor",
    "DreamHome Master",
    "EstateSmart Hub",
    "PropMap Pro",
    "LandTrack AI",
    "Estate Finder Lite",
    "Realty Scout Pro",
    "HomeAxis Navigator",
    "GeoTrail Realty",
    "LandVision Master",
    "UrbanDream Navigator",
    "EstatePath Finder",
    "DreamKey Master",
    "Estate Matrix Pro",
    "PropLink Navigator",
    "LandScope Insight",
    "Estate Guide Pro",
    "SmartDream Navigator",
    "GeoVision Realty",
    "UrbanNest Pro",
    "EstateSeeker AI",
    "LandSpot Finder",
    "DreamLocator 360",
    "GeoKey Navigator",
    "SmartLand Hub",
    "Estate Visionary Pro",
    "PropLink AI",
    "GeoTrail Navigator",
    "DreamNest Explorer",
    "Estate Scout 360",
    "LandVision Finder",
    "UrbanMap Pro",
    "EstateTrack Solutions",
    "PropPath Navigator",
    "Estate360 Navigator",
    "LandView Master",
    "GeoKey Pro",
    "PropTrail Explorer",
    "UrbanTrack Finder",
    "Estate Guide Lite",
    "SmartPath Navigator",
    "DreamAxis Pro",
    "GeoPath Realty",
    "LandSync Lite",
    "Estate Insight Pro",
    "PropKey Navigator",
    "GeoDream Explorer",
    "SmartHome Path",
    "LandMark Navigator",
    "DreamSphere Pro",
    "Estate Link Master",
    "UrbanFinder AI",
    "SmartNest Explorer",
    "LandTrack Navigator Pro",
    "GeoTrail Solutions",
    "PropVision Hub",
    "DreamKey Finder",
    "Estate Axis Pro",
    "SmartLand Link",
    "PropTrack Explorer",
    "DreamLand Master",
    "GeoNest Finder",
    "SmartTrack Navigator",
    "Estate Axis Navigator",
    "LandTrail Master",
    "Estate Insight Master",
    "DreamScope Hub",
    "GeoSphere Navigator",
    "EstateNest Finder",
    "PropInsight Lite",
    "DreamHome Map",
    "EstateScope Navigator",
    "SmartLand Guide",
    "GeoLand Master",
    "DreamLand Navigator",
    "UrbanEstate Master",
    "EstatePath Pro",
    "GeoTrack Finder",
    "SmartNest Hub",
    "EstateGuide Solutions",
    "LandMaster Finder",
    "UrbanTrail Pro",
    "SmartAxis Navigator",
    "DreamEstate Finder",
    "PropNest Lite",
    "Estate360 Finder",
    "GeoNest Navigator",
    "Estate Insight Hub",
    "UrbanKey Pro",
    "DreamLand Guide",
    "GeoEstate Solutions",
    "SmartLand Navigator Pro",
    "PropVision Finder",
    "DreamTrail Explorer",
    "EstateTrack Master",
    "GeoLand Solutions",
    "PropNavigator AI",
    "SmartPath Finder",
    "GeoTrail Finder",
    "EstateScout Lite",
    "DreamLocator Explorer",
    "UrbanLand Finder",
]

descriptions = [
    "A cutting-edge platform that leverages technology to streamline real estate transactions and property exploration.",
    "An AI-powered tool that helps users locate their dream properties with ease and precision.",
    "Navigate through luxurious estates and discover properties tailored to your dreams.",
    "A comprehensive mapping solution for tracking and exploring available land opportunities.",
    "A data-driven platform providing deep insights into property trends and valuations.",
    "Broaden your real estate horizons with this advanced property exploration tool.",
    "Envision your future with a platform that redefines the property search experience.",
    "AI-based real estate assistance to match you with the perfect property.",
    "Master the real estate market with our interactive and detailed mapping features.",
    "Embark on a quest for the perfect home with our easy-to-use navigation system.",
    "Streamline your real estate needs with our comprehensive property grid system.",
    "Discover properties with geographic and market insights tailored for you.",
    "Experience properties in 360-degree views for a complete virtual exploration.",
    "Your guiding light to finding the ideal estate in your desired location.",
    "Pinpoint your dream home with unmatched accuracy and simplicity.",
    "Navigate urban landscapes to find premium estate options in bustling cities.",
    "A smart tool that simplifies complex real estate decisions with expert guidance.",
    "Find the right property faster with our intelligent property matching system.",
    "A seamless experience for real estate transactions, from search to closing.",
    "Get instant access to the best real estate deals with just a click.",
    "The ultimate property search tool designed for real estate professionals and buyers.",
    "An intuitive platform for discovering the most sought-after properties in the market.",
    "Navigate through different neighborhoods and cities with our dynamic map.",
    "Make smarter property investments with our detailed market analysis tools.",
    "Find your ideal home or investment property with our advanced filters and search options.",
    "An AI-driven property recommendation engine that tailors options to your preferences.",
    "Track property prices and trends in real-time with our live market data.",
    "A unique platform designed to simplify the complex process of property investment.",
    "Explore properties like never before with our interactive 3D map features.",
    "Find your next real estate investment with the help of our data-driven insights.",
    "Discover hidden property gems with our advanced search filters.",
    "A one-stop platform for buying, selling, and investing in real estate.",
    "Real-time property price updates and trend analysis at your fingertips.",
    "Unlock the power of property data and make informed real estate decisions.",
    "A comprehensive property search tool designed for modern investors and homebuyers.",
    "Get the latest market trends, property valuations, and investment opportunities.",
    "Streamline your property search with our fast and reliable database search engine.",
    "Search for homes, apartments, and land with ease using our user-friendly platform.",
    "Discover the best properties in your area with our advanced geolocation tools.",
    "Find properties that match your specific criteria with our detailed search options.",
    "A platform designed to simplify the buying, selling, and renting process.",
    "Get personalized property recommendations based on your preferences and search history.",
    "Discover new investment opportunities in real estate with our AI-powered platform.",
    "Explore properties in different cities and neighborhoods with ease using our map tool.",
    "Analyze property prices, trends, and forecasts to make smarter real estate decisions.",
    "Find the best deals on properties with our expert-backed market insights.",
    "Streamline your home buying process with our innovative property management tools.",
    "Explore top-rated neighborhoods and properties using our interactive map features.",
    "A data-driven platform designed to help you find the perfect home or investment property.",
    "Stay updated on the latest real estate market trends and property values.",
    "Find your next property investment with our powerful property search engine.",
    "Get a complete picture of the real estate market with our detailed property reports.",
    "A property platform designed to connect buyers, sellers, and investors in real time.",
    "The smartest way to find real estate properties that match your criteria.",
    "Get real-time alerts on new property listings and market changes.",
    "Track property trends and valuations to make better investment decisions.",
    "Discover real estate investment opportunities that fit your goals and budget.",
    "Find your ideal property faster with our intuitive search features.",
    "A platform designed to provide real-time insights into the property market.",
    "Explore properties and neighborhoods with our interactive, high-definition maps.",
    "Make more informed real estate decisions with our in-depth market analysis tools.",
    "Find the perfect property for your needs with our advanced search filters.",
    "Stay ahead of the competition with our real-time property market insights.",
    "Explore new property opportunities based on your location, budget, and preferences.",
    "Get personalized property recommendations from our AI-driven platform.",
    "Track the latest real estate trends, prices, and forecasts with ease.",
    "Simplify your property search with our easy-to-use search engine and filters.",
    "A real estate platform designed to help you buy, sell, or invest with confidence.",
    "Discover properties that fit your lifestyle, preferences, and budget.",
    "Find properties faster with our fast, intuitive search engine.",
    "Analyze property values, trends, and potential investment opportunities.",
    "Search for properties based on location, price, and other custom criteria.",
    "Get expert recommendations and market insights to make smarter property decisions.",
    "Track the best deals in real estate and stay updated on market changes.",
    "Find the right home for you and your family with our intuitive property search tools.",
    "Explore real estate listings in your desired location and find the best deals.",
    "A platform that combines property search, analysis, and market insights in one place.",
    "Discover properties that are tailored to your needs with our powerful search engine.",
    "Stay updated on the best real estate deals with our real-time alerts and notifications.",
    "Find the best property investments with our comprehensive market analysis tools.",
    "Explore properties in your area with detailed listings and photos.",
    "Get expert-backed property recommendations based on your budget and preferences.",
    "Search for homes, apartments, and land with ease using our advanced filters.",
    "Find your ideal property faster with our search engine powered by AI technology.",
    "Analyze property prices and trends to make informed investment decisions.",
    "Get personalized property alerts based on your search preferences.",
    "A platform designed to help you find the perfect home or investment property quickly.",
    "Discover properties that match your lifestyle, preferences, and investment goals.",
    "Track the real estate market with live updates on property values and trends.",
    "Search for properties using advanced filters to match your exact criteria.",
    "A powerful platform designed to help you make smarter property decisions.",
    "Discover hidden gems in the property market with our search and analysis tools.",
    "Explore real estate listings from top neighborhoods and cities around the world.",
    "Analyze the real estate market to identify profitable investment opportunities.",
    "Find properties based on location, price, and your specific investment goals.",
    "Stay up-to-date with the latest property listings, market trends, and investment insights.",
    "Search for properties in various categories like residential, commercial, and industrial.",
    "Get access to the latest real estate listings, market updates, and investment opportunities.",
    "Discover real estate investment opportunities in up-and-coming markets.",
    "Track property prices and market trends to make smarter investment decisions.",
    "Explore real estate opportunities in various locations and price ranges.",
    "A comprehensive platform that helps you make informed decisions in the real estate market.",
    "Search for properties based on a variety of criteria to find the perfect fit for you.",
    "Track property trends and get alerts on new listings in your area of interest.",
    "A platform designed to help you quickly find and invest in real estate properties.",
    "Get detailed property reports and insights to make informed real estate decisions.",
    "Explore real estate listings with advanced search filters and detailed photos.",
    "Analyze property trends and investment opportunities with real-time data.",
    "Stay informed on the latest real estate news, trends, and investment opportunities.",
    "Find the perfect property for your needs with advanced search and filter options.",
    "A powerful real estate platform designed to connect buyers and sellers in real time.",
    "Discover properties that match your needs with our easy-to-use property search engine.",
    "Track property prices, trends, and market changes to make smarter investment decisions.",
    "Get personalized property alerts based on your search history and preferences.",
    "Find the best real estate deals with the help of our intelligent property recommendations.",
    "Explore properties in your area with detailed listings and photos.",
    "A smart platform that simplifies property searching and buying.",
    "Find your next real estate investment with detailed property insights and market analysis.",
    "Get expert real estate advice and recommendations based on your goals and budget.",
    "Discover the best properties for sale or rent with ease and confidence.",
    "Explore new real estate opportunities and trends with our interactive platform.",
    "Track property market trends to stay informed on price changes and investment opportunities.",
    "Find properties based on your preferred location, budget, and investment goals.",
    "Analyze property prices, rental yields, and market trends to make smarter decisions.",
    "Search for properties in your desired area using advanced location-based filters.",
    "Stay updated on real estate market news, listings, and investment opportunities.",
    "Find properties for sale or rent using our smart search engine and filtering options.",
    "Track property values and market trends to stay ahead of the real estate market.",
    "Discover new investment opportunities in the real estate market with our platform.",
    "Explore a wide range of real estate listings, including homes, apartments, and land."
]

# %%
categories = [
    "Residential",
    "Commercial",
    "Industrial",
    "Land",
    "Luxury Properties",
    "Investment Properties",
    "Vacation Homes",
    "Urban Properties",
    "Rural Properties",
    "Foreclosures",
    "New Construction",
    "Pre-owned Homes",
    "High-end Real Estate",
    "Starter Homes",
    "Retirement Communities",
    "Gated Communities",
    "Beachfront Properties",
    "Mountain Homes",
    "Farm and Ranch",
    "Green and Sustainable Properties",
    "Real Estate Auctions",
    "Student Housing",
    "Short-Term Rentals",
    "Long-Term Rentals",
    "Corporate Housing",
    "Multi-Family Units",
    "Luxury Rentals",
    "Real Estate Development",
    "Recreational Properties",
    "Historic Properties",
    "Fixer-Uppers",
    "Vacant Lots",
    "Foreclosed Homes",
    "Real Estate Investment Trusts (REITs)",
    "Real Estate Financing",
    "Property Management",
    "Urban Redevelopment",
    "Senior Living",
    "Affordable Housing",
    "Co-working Spaces",
    "Smart Homes",
    "Real Estate Crowdfunding",
    "Real Estate Brokerage",
    "Commercial Leasing",
    "Retail Spaces",
    "Office Spaces",
    "Warehouse Properties",
    "Business Park Properties",
    "Mixed-Use Developments",
    "Eco-Friendly Homes",
    "Townhouses",
    "Villas",
    "Penthouses",
    "Apartments",
    "Lofts",
    "Condos",
    "Co-living Spaces",
    "Manufactured Homes",
    "Tiny Homes",
    "Mobile Homes",
    "Vacation Rentals",
    "Cabins",
    "Cottages",
    "Boathouses",
    "Eco Communities",
    "Student Apartments",
    "Land Investment",
    "Real Estate Auctions",
    "Real Estate Agencies",
    "Property Investment Firms",
    "Real Estate Marketing",
    "Foreclosure Auctions",
    "Green Building Properties",
    "High-Rise Apartments",
    "Suburban Homes",
    "Rural Retreats",
    "Single-Family Homes",
    "Pet-Friendly Properties",
    "Investment Opportunities",
    "Luxury Commercial Spaces",
    "Real Estate Auctions",
    "Residential Leasing",
    "Specialty Properties",
    "Real Estate Consulting",
    "Real Estate Syndication",
    "Real Estate Partnerships",
    "Luxury Vacation Homes",
    "Historic Residences",
    "Second Homes",
    "Holiday Homes",
    "New Developments",
    "Real Estate Agents",
    "Real Estate Technology",
    "Real Estate Marketing Platforms",
    "Affordable Housing Initiatives",
    "Short-Term Lease Properties",
    "Retail Lease Spaces",
    "Exclusive Estates",
    "Retirement Living Communities",
    "Private Islands",
    "Real Estate Investment Groups",
    "Luxury Retirement Homes",
    "Mixed-Use Commercial Properties",
    "Investment Apartments",
    "Real Estate Auctions Online",
    "Co-op Housing",
    "Eco Villas",
    "Off-Grid Properties",
    "Heritage Properties",
    "Resort Properties",
    "Unique Properties",
    "Seaside Properties",
    "Holiday Resorts",
    "Lakefront Properties",
    "Waterfront Properties",
    "Penthouse Suites",
    "Luxury Office Spaces",
    "Business Centers",
    "Real Estate Leads",
    "Real Estate Technology Solutions",
    "International Properties",
    "Global Real Estate Investments",
    "High-Return Properties",
    "Overseas Properties",
    "Offshore Investments",
    "Real Estate Tax Strategies",
    "Real Estate Financing Options",
    "Property Development Consulting",
    "Smart Home Properties",
    "Vacation Investment Properties",
    "City Properties",
    "Country Properties",
    "Real Estate Law",
    "Real Estate Funding",
    "Real Estate Investment Courses",
    "Holiday Cottage Rentals",
    "Urban Apartments",
    "Second Home Investment",
    "Exclusive Apartments",
    "New Build Homes",
    "Mortgage Solutions",
    "Real Estate Trade Associations",
    "Properties with Water Access",
    "Properties with Acreage",
    "Affordable Housing Developments",
    "Real Estate Digital Platforms",
    "Property Flipping",
    "Houseboats",
    "Commercial Real Estate Development",
    "Industrial Parks",
    "Real Estate Listings",
    "Short-Term Rental Management",
    "Mixed Use Real Estate Projects"
]

subcategories = [
    "Single-Family Homes",
    "Townhouses",
    "Apartments",
    "Condos",
    "Lofts",
    "Villas",
    "Penthouses",
    "Starter Homes",
    "Luxury Homes",
    "Senior Living",
    "Co-living Spaces",
    "Eco-Friendly Homes",
    "Tiny Homes",
    "Mobile Homes",
    "Multi-Family Homes",
    "Gated Communities",
    "Retail Spaces",
    "Office Spaces",
    "Business Park Properties",
    "Warehouses",
    "Industrial Properties",
    "Mixed-Use Developments",
    "Co-working Spaces",
    "Hotel Properties",
    "Shopping Malls",
    "Medical Offices",
    "Restaurants",
    "Commercial Leasing",
    "Commercial Investment",
    "Factories",
    "Warehouses",
    "Distribution Centers",
    "Manufacturing Plants",
    "Storage Units",
    "Industrial Parks",
    "Heavy Equipment Facilities",
    "Vacant Land",
    "Agricultural Land",
    "Farm and Ranch",
    "Development Land",
    "Recreational Land",
    "Timberland",
    "Hunting Land",
    "Commercial Land",
    "Residential Land",
    "Subdividable Land",
    "Luxury Homes",
    "Luxury Condos",
    "Penthouses",
    "Villas",
    "Private Islands",
    "Historic Properties",
    "Exclusive Estates",
    "Luxury Apartments",
    "Luxury Vacation Homes",
    "Mansions",
    "Luxury Rentals",
    "Rental Properties",
    "Fix-and-Flip Properties",
    "Multi-Family Units",
    "Commercial Real Estate",
    "REITs (Real Estate Investment Trusts)",
    "Vacation Rentals",
    "Distressed Properties",
    "Foreclosures",
    "Pre-construction Properties",
    "Tax Lien Properties",
    "Beachfront Properties",
    "Mountain Retreats",
    "Lakefront Properties",
    "Resorts",
    "Second Homes",
    "Holiday Homes",
    "Cabins",
    "Cottages",
    "Boathouses",
    "Luxury Villas",
    "City Apartments",
    "Lofts",
    "Condos",
    "Penthouse Suites",
    "Commercial Properties",
    "Office Spaces",
    "Mixed-Use Developments",
    "High-Rise Buildings",
    "Retail Spaces",
    "Urban Co-living Spaces",
    "Farm and Ranch",
    "Agricultural Land",
    "Country Homes",
    "Off-Grid Properties",
    "Farmhouses",
    "Recreational Land",
    "Retreats",
    "Hunting Properties",
    "Bank-Owned Properties",
    "Short Sales",
    "Distressed Homes",
    "Pre-Foreclosures",
    "Auction Properties",
    "New Homes",
    "Pre-Construction Properties",
    "Luxury New Builds",
    "Modern Homes",
    "Energy Efficient Homes",
    "Smart Homes",
    "Eco-Friendly New Developments",
    "Previously Owned Homes",
    "Resale Properties",
    "Renovated Homes",
    "Starter Homes",
    "Vintage Homes",
    "Fixer-Uppers",
    "Luxury Villas",
    "Mansions",
    "Private Islands",
    "Exclusive Estates",
    "High-Rise Penthouses",
    "Luxury Condos",
    "Senior Living",
    "Independent Living",
    "Assisted Living",
    "Gated Retirement Communities",
    "Active Adult Communities",
    "Private Communities",
    "Luxury Gated Estates",
    "Gated Condos",
    "Secure Developments",
    "Golf Course Communities",
    "Retirement Gated Communities",
    "Green Homes",
    "Solar-Powered Homes",
    "Passive Houses",
    "Energy Efficient Properties",
    "Sustainable Living",
    "Smart Homes",
    "Foreclosure Auctions",
    "Tax Lien Auctions",
    "Property Auctions",
    "Online Auctions",
    "Live Auctions",
    "Student Apartments",
    "Shared Housing",
    "Dormitory Style Living",
    "Short-Term Rentals for Students",
    "Vacation Homes",
    "Airbnb Rentals",
    "Holiday Homes",
    "Short-Term Rental Properties",
    "Apartments for Rent",
    "Houses for Rent",
    "Office Spaces for Rent",
    "Long-Term Commercial Leasing",
    "Shared Office Spaces",
    "Business Centers",
    "Private Offices",
    "Virtual Offices",
    "Smart Apartments",
    "Automated Homes",
    "Homes with Integrated Technology",
    "IoT (Internet of Things) Properties",
    "Rental Property Management",
    "Real Estate Management Services",
    "Building Management",
    "Commercial Property Management",
    "Tenant Services",
    "Retail Leasing",
    "Office Leasing",
    "Warehouse Leasing",
    "Flexible Office Space",
    "Shops",
    "Strip Malls",
    "Standalone Stores",
    "Commercial Retail Properties",
    "Private Offices",
    "Co-working Offices",
    "Leased Office Space",
    "Executive Suites",
    "Business Centers",
    "Industrial Warehouses",
    "Storage Facilities",
    "Distribution Centers",
    "Logistics Centers",
    "Residential and Commercial Spaces",
    "Urban Developments",
    "Live/Work Spaces",
    "Retail and Residential Combinations",
    "Mortgage Loans",
    "Property Financing",
    "Real Estate Loans",
    "Commercial Loans",
    "Hard Money Loans",
    "Residential REITs",
    "Commercial REITs",
    "Mortgage REITs",
    "Private REITs",
    "PropTech",
    "Real Estate Apps",
    "Property Search Platforms",
    "Virtual Tours",
    "Real Estate CRM"
]

# %%
listedin=["sell","rent"]
price = [
    1227702, 1352839, 4991441, 2501225, 4081127, 3133869, 1135608, 2050940, 1860261, 4397951,
    4332994, 3993518, 3703810, 1350052, 2600647, 3066221, 2456304, 3388272, 4221909, 4737316,
    2824307, 2683015, 2434206, 1669326, 4051933, 2527494, 2133778, 4321688, 2029432, 2749886,
    3455045, 1593255, 2913103, 2300286, 3935871, 3946176, 3224294, 4785202, 3320715, 2896058,
    3368687, 4917630, 1005587, 3411974, 2287441, 2582518, 3795810, 4758939, 3503585, 1078799,
    2499132, 4465765, 1947423, 1603941, 2462234, 3959387, 1868913, 1968413, 4058904, 2491649,
    4436729, 1785825, 1525018, 3244849, 3971757, 3962346, 4572034, 4501542, 1881813, 3916489,
    4313262, 4969010, 3284464, 2739140, 1593734, 4182181, 1559131, 3250398, 2326292, 1678955,
    1619206, 2832648, 4819793, 3645792, 1325458, 2035519, 2314494, 4935668, 1213601, 1791128,
    3381138, 2863487, 2199909, 4467866, 2476683, 2193544, 4672022, 4291196, 4285019, 3574056,
    3947894, 2401488, 2249271, 4789897, 1609061, 4462120, 4812672, 1597065, 1353519, 2131005,
    4584995, 1341741, 4899664, 2333317, 3187303, 2280821, 3588855, 4939902, 4823873, 4202399,
    1936957, 3806381, 1560205, 1185798, 3861049, 4339460, 4102428, 4563154, 4124752, 3445656,
    3272618, 3247114, 4064530, 2331089, 3007788, 2858108, 1633265, 2706621, 2114256, 4606050,
    3823385, 3540287, 1488360, 4225686, 2848320, 3404202, 2313343, 4388493, 2450919, 1919811,
    4551724, 2145547, 3627320, 3810248, 1231334, 4302083, 2494368, 1814731, 3339236, 1988333,
    4317974, 3394082, 1208921, 1364901, 1536011, 2101399, 3922552, 1075746, 1228525, 2595963,
    4938740, 1502912, 1410731, 2014505, 4936389, 2344603, 3618300, 2723741, 3099332, 3853454,
    4342533, 4361462, 4173357, 4934777, 2018251, 4089161, 4666742, 3662550, 2687958, 2652387,
    2269253, 1330696, 2032119, 4812419, 2935051, 4578707, 4927067, 2802295, 1403363, 4139862
]
propertystatus=["Veryfied","Pending"]
status=["true","false"]
rejectreason=["null"]
user_id = [
    2,4
]
propertymanagerid=[1]
bookingAmount=["0"]
markasFavorite=[True,False]
propertystep=[5]
ipfs=["null"]

random_amenities = [
    "Garage", "Parking Space", "Garden", "Patio", "Tennis Court",
    "Swimming Pool", "Basketball Court", "Skating Rink", "Playground",
    "Outdoor Seating", "Rooftop Terrace", "Backyard", "Private Beach Access",
    "Boathouse", "Outdoor Kitchen", "Fire Pit", "Picnic Area", "Helipad",
    "Private Dock", "Green Roof",
    "Gym", "Fitness Center", "Yoga Studio", "Dance Room", "Game Room",
        "Indoor Sports Area", "Squash Court", "Golf Simulator", "Bowling Alley",
        "Mini Golf", "Virtual Reality Room", "Archery Range", "Billiards Room",
        "Table Tennis Room", "Badminton Court", "Rock Climbing Wall", "Sports Bar",
        "Spa Room", "Massage Room", "Juice Bar",
        "24/7 Security", "CCTV Surveillance", "Gated Community", "Fire Alarm System",
        "Emergency Exit", "Panic Room", "Smart Door Lock", "Intercom Facility",
        "Video Door Phone", "Security Patrols", "Smoke Detectors", "First Aid Room",
        "Seismic-Resistant Structure", "Storm Shelter", "Security Cabin", "Guard Room",
        "Access Control System", "Fire Sprinklers", "Flood Lights", "Perimeter Wall",
        "Kids Play Area", "Daycare Center", "Treehouse", "Kids Pool", "Splash Pad",
        "School Bus Pick-Up Zone", "Study Room", "Library", "Storytelling Room",
        "Art & Craft Room", "Toy Library", "Homework Station", "Sensory Play Zone",
        "Parent Lounge", "Sandpit", "Music Room", "Drama Studio", "Childproof Fencing",
        "Family Garden", "Multi-Purpose Hall",
        "Balcony", "Terrace", "Fireplace", "Jacuzzi", "Air Conditioning",
        "Heated Floors", "Smart Thermostat", "Built-In Wardrobes", "Walk-In Closet",
        "Laundry Room", "Drying Area", "Mudroom", "Pantry", "Wine Cellar",
        "Home Theater", "Private Elevator", "Central Heating", "Double Glazing",
        "Soundproofing", "Home Office",
        "Solar Panels", "Rainwater Harvesting", "Composting Unit", "Greenhouse",
        "Bicycle Storage", "Electric Vehicle Charging Station", "Recycling Area",
        "Greywater System", "Energy-Efficient Appliances", "Low-E Glass Windows",
        "Green Landscaping", "LED Lighting", "Solar Water Heater", "Wind Turbine",
        "Sustainable Materials", "Green Building Certification", "Organic Garden",
        "Thermal Insulation", "Water Purification System", "Native Plants",
        "Spa", "Sauna", "Steam Room", "Infinity Pool", "Private Pool",
        "Wine Tasting Room", "Butler Service", "Concierge Service", "Personal Chef",
        "Luxury Finishes", "Sky Lounge", "Private Gym", "Home Automation System",
        "Art Gallery Space", "Piano Room", "Private Theater", "Exclusive Entrance",
        "Luxury Lobby", "Designer Lighting", "Premium Flooring",
        "Clubhouse", "Community Hall", "Business Center", "Coworking Space",
        "Party Lawn", "Barbecue Area", "Cafeteria", "Convenience Store",
        "Pharmacy", "ATM", "Open Air Theater", "Event Space", "Amphitheater",
        "Garden Walkways", "Gazebo", "Outdoor Yoga Deck", "Pet Park",
        "Community Garden", "Market Zone", "Food Truck Parking",
        "Clinic", "Pharmacy", "First Aid Room", "Wellness Center", "Meditation Area",
        "Detox Center", "Therapy Room", "Rehabilitation Center", "Acupuncture Room",
        "Herbal Garden", "Organic Store", "Hydrotherapy Pool", "Aromatherapy Room",
        "Salt Room", "Vitamin Therapy Station", "Oxygen Bar", "Herbal Steam Room",
        "Ayurvedic Spa", "Naturopathy Center", "Nutrition Consultation Room",
        "Bike Rack", "Storage Unit", "Courier Room", "Parcel Lockers", "Workshop Area",
        "Tool Shed", "Car Wash Area", "Dry Cleaning Service", "Wi-Fi Hotspots",
        "Charging Stations", "Shared Workspace", "CCTV Room", "Maintenance Office",
        "Guest Parking", "Driver's Lounge", "Electric Gate", "Loading Dock",
        "Private Garage", "Roof Access", "Customizable Interiors"
]


random_facilities = [
    "Temple", "Church", "Mosque", "Gurudwara", "Synagogue", "Pagoda", "Shrine", "Monastery", "Jain Temple", "Cathedral",
    "School", "College", "University", "Library", "Coaching Center", "Kindergarten", "Play School", "Research Institute", "Vocational Training Center", "Music School",
    "Hospital", "Clinic", "Nursing Home", "Pharmacy", "Diagnostic Center", "Rehabilitation Center", "Veterinary Clinic", "Dental Clinic", "Maternity Center", "Eye Care Center",
    "Park", "Playground", "Botanical Garden", "Zoo", "Theme Park", "Water Park", "National Park", "Community Garden", "Walking Trails", "Outdoor Gym",
    "Shopping Mall", "Supermarket", "Grocery Store", "Retail Market", "Department Store", "Boutique", "Furniture Store", "Electronics Store", "Jewelry Store", "Pharmacy",
    "Bus Stop", "Metro Station", "Train Station", "Airport", "Taxi Stand", "Bicycle Rental", "Electric Vehicle Charging Station", "Ferry Terminal", "Car Rental", "Helipad",
    "Restaurant", "Cafe", "Fast Food Outlet", "Food Court", "Bakery", "Ice Cream Parlor", "Fine Dining", "Street Food Stall", "Juice Bar", "Wine Shop",
    "Stadium", "Sports Complex", "Cricket Ground", "Football Field", "Swimming Pool", "Tennis Court", "Gym", "Skating Rink", "Martial Arts Studio", "Cycling Track",
    "Movie Theater", "Concert Hall", "Art Gallery", "Museum", "Auditorium", "Dance Studio", "Drama Theater", "Exhibition Center", "Bookstore", "Cultural Center",
    "Bank", "ATM", "Post Office", "Police Station", "Fire Station", "Community Hall", "Wedding Hall", "Pet Care Center", "Courier Service", "Gas Station"
]
# propertyid=[1,2,3,4,5]

# %% [markdown]
# SQLALchemy

# %%
# # prompt: connect to postgres server using python
# !pip install psycopg2-binary
# !pip install SQLAlchemy
# !pip install alembic

# %%
import os
from tqdm import tqdm
import pandas as pd
import re
import numpy as np
import chardet
pd.set_option('display.max_colwidth', None)
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError

# %%
host= "proptechdb.cwrq9y4ax7rv.ap-south-1.rds.amazonaws.com"
user= "postgres"
password= "Postgres123"
database= "proptech"
port=5432

# %%
engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")
# Test the connection
try:
    with engine.connect() as connection:
        print(f"Successfully connected to the PostgreSQL database: {database}")
except SQLAlchemyError as e:
    print(f"Error connecting to the PostgreSQL database: {e}")
# Out:
# Successfully connected to the PostgreSQL database: proptech

# %%
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey, DateTime, Text, Boolean, DOUBLE_PRECISION,JSON
from sqlalchemy.orm import declarative_base, relationship, Session, sessionmaker
from sqlalchemy.dialects.postgresql import TIMESTAMP
from sqlalchemy.sql import func
from sqlalchemy.dialects.postgresql import insert
from sqlalchemy.exc import SQLAlchemyError

import datetime

# %%
random_amenities = [
    "Garage", "Parking Space", "Garden", "Patio", "Tennis Court",
    "Swimming Pool", "Basketball Court", "Skating Rink", "Playground",
    "Outdoor Seating", "Rooftop Terrace", "Backyard", "Private Beach Access",
    "Boathouse", "Outdoor Kitchen", "Fire Pit", "Picnic Area", "Helipad",
    "Private Dock", "Green Roof",
    "Gym", "Fitness Center", "Yoga Studio", "Dance Room", "Game Room",
        "Indoor Sports Area", "Squash Court", "Golf Simulator", "Bowling Alley",
        "Mini Golf", "Virtual Reality Room", "Archery Range", "Billiards Room",
        "Table Tennis Room", "Badminton Court", "Rock Climbing Wall", "Sports Bar",
        "Spa Room", "Massage Room", "Juice Bar",
        "24/7 Security", "CCTV Surveillance", "Gated Community", "Fire Alarm System",
        "Emergency Exit", "Panic Room", "Smart Door Lock", "Intercom Facility",
        "Video Door Phone", "Security Patrols", "Smoke Detectors", "First Aid Room",
        "Seismic-Resistant Structure", "Storm Shelter", "Security Cabin", "Guard Room",
        "Access Control System", "Fire Sprinklers", "Flood Lights", "Perimeter Wall",
        "Kids Play Area", "Daycare Center", "Treehouse", "Kids Pool", "Splash Pad",
        "School Bus Pick-Up Zone", "Study Room", "Library", "Storytelling Room",
        "Art & Craft Room", "Toy Library", "Homework Station", "Sensory Play Zone",
        "Parent Lounge", "Sandpit", "Music Room", "Drama Studio", "Childproof Fencing",
        "Family Garden", "Multi-Purpose Hall",
        "Balcony", "Terrace", "Fireplace", "Jacuzzi", "Air Conditioning",
        "Heated Floors", "Smart Thermostat", "Built-In Wardrobes", "Walk-In Closet",
        "Laundry Room", "Drying Area", "Mudroom", "Pantry", "Wine Cellar",
        "Home Theater", "Private Elevator", "Central Heating", "Double Glazing",
        "Soundproofing", "Home Office",
        "Solar Panels", "Rainwater Harvesting", "Composting Unit", "Greenhouse",
        "Bicycle Storage", "Electric Vehicle Charging Station", "Recycling Area",
        "Greywater System", "Energy-Efficient Appliances", "Low-E Glass Windows",
        "Green Landscaping", "LED Lighting", "Solar Water Heater", "Wind Turbine",
        "Sustainable Materials", "Green Building Certification", "Organic Garden",
        "Thermal Insulation", "Water Purification System", "Native Plants",
        "Spa", "Sauna", "Steam Room", "Infinity Pool", "Private Pool",
        "Wine Tasting Room", "Butler Service", "Concierge Service", "Personal Chef",
        "Luxury Finishes", "Sky Lounge", "Private Gym", "Home Automation System",
        "Art Gallery Space", "Piano Room", "Private Theater", "Exclusive Entrance",
        "Luxury Lobby", "Designer Lighting", "Premium Flooring",
        "Clubhouse", "Community Hall", "Business Center", "Coworking Space",
        "Party Lawn", "Barbecue Area", "Cafeteria", "Convenience Store",
        "Pharmacy", "ATM", "Open Air Theater", "Event Space", "Amphitheater",
        "Garden Walkways", "Gazebo", "Outdoor Yoga Deck", "Pet Park",
        "Community Garden", "Market Zone", "Food Truck Parking",
        "Clinic", "Pharmacy", "First Aid Room", "Wellness Center", "Meditation Area",
        "Detox Center", "Therapy Room", "Rehabilitation Center", "Acupuncture Room",
        "Herbal Garden", "Organic Store", "Hydrotherapy Pool", "Aromatherapy Room",
        "Salt Room", "Vitamin Therapy Station", "Oxygen Bar", "Herbal Steam Room",
        "Ayurvedic Spa", "Naturopathy Center", "Nutrition Consultation Room",
        "Bike Rack", "Storage Unit", "Courier Room", "Parcel Lockers", "Workshop Area",
        "Tool Shed", "Car Wash Area", "Dry Cleaning Service", "Wi-Fi Hotspots",
        "Charging Stations", "Shared Workspace", "CCTV Room", "Maintenance Office",
        "Guest Parking", "Driver's Lounge", "Electric Gate", "Loading Dock",
        "Private Garage", "Roof Access", "Customizable Interiors"
]



random_facilities = [
    "Temple", "Church", "Mosque", "Gurudwara", "Synagogue", "Pagoda", "Shrine", "Monastery", "Jain Temple", "Cathedral",
    "School", "College", "University", "Library", "Coaching Center", "Kindergarten", "Play School", "Research Institute", "Vocational Training Center", "Music School",
    "Hospital", "Clinic", "Nursing Home", "Pharmacy", "Diagnostic Center", "Rehabilitation Center", "Veterinary Clinic", "Dental Clinic", "Maternity Center", "Eye Care Center",
    "Park", "Playground", "Botanical Garden", "Zoo", "Theme Park", "Water Park", "National Park", "Community Garden", "Walking Trails", "Outdoor Gym",
    "Shopping Mall", "Supermarket", "Grocery Store", "Retail Market", "Department Store", "Boutique", "Furniture Store", "Electronics Store", "Jewelry Store", "Pharmacy",
    "Bus Stop", "Metro Station", "Train Station", "Airport", "Taxi Stand", "Bicycle Rental", "Electric Vehicle Charging Station", "Ferry Terminal", "Car Rental", "Helipad",
    "Restaurant", "Cafe", "Fast Food Outlet", "Food Court", "Bakery", "Ice Cream Parlor", "Fine Dining", "Street Food Stall", "Juice Bar", "Wine Shop",
    "Stadium", "Sports Complex", "Cricket Ground", "Football Field", "Swimming Pool", "Tennis Court", "Gym", "Skating Rink", "Martial Arts Studio", "Cycling Track",
    "Movie Theater", "Concert Hall", "Art Gallery", "Museum", "Auditorium", "Dance Studio", "Drama Theater", "Exhibition Center", "Bookstore", "Cultural Center",
    "Bank", "ATM", "Post Office", "Police Station", "Fire Station", "Community Hall", "Wedding Hall", "Pet Care Center", "Courier Service", "Gas Station"
]

# %%
# SQLAlchemy base and engine
Base = declarative_base()
# Define the Properties table model
class propertyamenities(Base):
    __tablename__ = "propertyamenities"
    id = Column(Integer, primary_key=True, autoincrement=True)
    amenities=Column(Text)
    facilities=Column(Text)
    propertyid=Column(Integer)
    createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
    updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())

# Create all tables
Base.metadata.create_all(engine)
Session=sessionmaker(bind=engine)
session=Session()

# %%
import random
import datetime
import json  # Import JSON module for serialization

# Assuming random_amenities and random_facilities are already initialized properly as lists

data_to_insert = []

for i in range(1, 12):
    # Ensure amenities and facilities are stored as lists
    amenities = list(random.sample(random_amenities, random.randint(1, 20)))
    facilities = list(random.sample(random_facilities, random.randint(1, 20)))

    # Print for debugging
    print(amenities)
    print(facilities)

    # Serialize lists to JSON strings
    amenities_json = json.dumps(amenities)
    facilities_json = json.dumps(facilities)

    new_property = propertyamenities(
        amenities=amenities_json,  # Store as JSON string
        facilities=facilities_json,  # Store as JSON string
        createdAt=datetime.datetime.now(datetime.timezone.utc),
        updatedAt=datetime.datetime.now(datetime.timezone.utc)
    )

    data_to_insert.append(new_property)

# Bulk save objects to session
session.bulk_save_objects(data_to_insert)
session.commit()












# import random
# data_to_insert=[]

# for i in range(1,2):
#    new_property=propertyamenities(
#        # Ensure amenities and facilities are stored as lists
#     amenities = list(random.sample(random_amenities, random.randint(1, len(random_amenities)))),
#     facilities = list(random.sample(random_facilities, random.randint(1, len(random_facilities)))),

#        createdAt= datetime.datetime.now(datetime.timezone.utc),
#         updatedAt= datetime.datetime.now(datetime.timezone.utc)
#    )
#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()
# Out:
# ['Fire Pit']
# ['Skating Rink', 'Gurudwara', 'Museum', 'Boutique', 'Dance Studio', 'Mosque', 'Monastery', 'Church', 'Rehabilitation Center', 'Pharmacy']
# ['Customizable Interiors', 'Recycling Area', 'Wind Turbine', 'Composting Unit', 'Concierge Service', 'Soundproofing', 'Bike Rack', 'Patio', 'Storage Unit', 'Pantry', 'Kids Play Area', 'Music Room', 'Daycare Center', 'Badminton Court', 'Business Center', 'Green Building Certification', 'Wi-Fi Hotspots', 'Roof Access', 'Flood Lights']
# ['Juice Bar', 'Drama Theater', 'Restaurant', 'Cathedral', 'ATM', 'Boutique', 'Pharmacy', 'Church', 'Supermarket', 'Cricket Ground', 'Playground']
# ['Study Room', 'Mudroom', 'Community Hall', 'Wine Cellar', 'Oxygen Bar', 'CCTV Room']
# ['Train Station', 'College', 'Wine Shop', 'Shopping Mall', 'Car Rental', 'Airport', 'Ice Cream Parlor', 'Cafe', 'Walking Trails', 'Retail Market', 'Boutique', 'Grocery Store']
# ['Gated Community', 'Rock Climbing Wall', 'Juice Bar', 'Fitness Center']
# ...

# %%
# # SQLAlchemy base and engine
# Base = declarative_base()
# # Define the Properties table model
# class properties(Base):
#     __tablename__ = "properties"
#     id = Column(Integer, primary_key=True, autoincrement=True)
#     title= Column(String)
#     description= Column(Text)
#     category=Column(String)
#     subcategory=Column(String)
#     listedin=Column(String)
#     price=Column(Integer)
#     propertystatus=Column(String)
#     status=Column(String)
#     rejectreason=Column(String)
#     userid=Column(Integer)
#     propertymanagerid=Column(Integer)
#     agentid=Column(Integer)
#     bookingAmount=Column(Integer)
#     markasFavorite=Column(Boolean)
#     propertystep=Column(Integer)
#     ipfs=Column(String)
#     createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
#     updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())

# # Create all tables
# Base.metadata.create_all(engine)
# Session=sessionmaker(bind=engine)
# session=Session()

# %%
# import random
# data_to_insert=[]

# for i in range(1,10):
#    new_property=properties(
#    title=random.choice(title_data),
#    description=random.choice(descriptions),
#    category=random.choice(categories),
#    subcategory=random.choice(subcategories),
#    listedin=random.choice(listedin),
#    price=random.choice(price),
#    propertystatus=random.choice(propertystatus),
#    status=random.choice(status),
#    rejectreason=random.choice(rejectreason),
#    userid=random.choice(user_id),
#    propertymanagerid=random.choice(propertymanagerid),
#    agentid=random.randint(0,1),  # Corrected agent id generation
#    bookingAmount=random.choice(bookingAmount),
#    markasFavorite=random.choice(markasFavorite),
#    propertystep=random.choice(propertystep),
#    ipfs=random.choice(ipfs),
#    createdAt= datetime.datetime.now(datetime.timezone.utc),
#    updatedAt= datetime.datetime.now(datetime.timezone.utc)
#    )
#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()

# %%
bedrooms=["1BHK","2BHK","3BHK","4BHK","5BHK"]
yearbuilt=["0-5 Years","0-3 Years","New Construcion","2003","2004"]
basement=["3","2","1","5","4"]

# %%
# # SQLAlchemy base and engine
# Base = declarative_base()
# # Define the Properties table model
# class propertydetails(Base):
#     __tablename__ = "propertydetails"
#     id = Column(Integer, primary_key=True, autoincrement=True)
#     sizeinft= Column(DOUBLE_PRECISION)
#     lotsizeinft= Column(DOUBLE_PRECISION)
#     rooms=Column(Integer)
#     bedrooms=Column(String)
#     bathrooms=Column(Integer)
#     parking=Column(Integer)
#     garages=Column(Integer)
#     garagesize=Column(Integer)
#     yearbuilt=Column(String)
#     availablefrom=Column(TIMESTAMP(timezone=True), server_default=func.now())
#     basement=Column(String)
#     facing=Column(String)
#     roofing=Column(String)
#     exteriormaterial=Column(String)
#     structuretype=Column(String)
#     flatno=Column(Integer)
#     floorsno=Column(Integer)
#     totalfloor=Column(Integer)
#     notes=Column(String)
#     refugearea=Column(String)
#     possession=Column(String)
#     furnish=Column(String)
#     propertyid=Column(Integer)
#     createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
#     updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())

# # Create all tables
# Base.metadata.create_all(engine)
# Session=sessionmaker(bind=engine)
# session=Session()

# %%
# from logging import root
# import random
# data_to_insert=[]

# for i in range(1,10):
#    new_property=propertydetails(
#     sizeinft=random.randint(100, 5000),  # Use randint for integer range
#     lotsizeinft=random.randint(100, 5000),  # Use randint for integer range
#     rooms=random.randint(3, 10),
#     bedrooms=random.choice(bedrooms),
#     bathrooms=random.randint(1,4),
#     parking=random.randint(1,5),
#     garages=random.randint(1,3),
#     garagesize=random.randint(100,2000),
#     yearbuilt=random.choice(yearbuilt),
#     availablefrom= datetime.datetime.now(datetime.timezone.utc),
#     basement=random.choice(basement),
#     facing=random.choice(["North","South","East","West","North-East","North-West","South-East","South-West"]),
#     roofing=random.choice(["No","Bricks","Carpet","Tiles"]),
#     exteriormaterial=random.choice(["Wood","Concrete","Brick","Stone"]),
#     structuretype = random.choice([None, "Type1", "Type2", "Type3"]),
#     flatno=random.randint(101,500),
#     floorsno=random.randint(1,15),
#     totalfloor=random.randint(1,15),
#     notes=random.choice(["null"]),
#     refugearea=random.choice(["Yes","No"]),
#     possession=random.choice(["Ready to move","under construction","upcomming"]),
#     furnish=random.choice(["Furnished","Semifurnished","Unfurnished"]),
#     # propertyid=random.randint(1,100),
#     createdAt= datetime.datetime.now(datetime.timezone.utc),
#     updatedAt= datetime.datetime.now(datetime.timezone.utc)
#     )
#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()

# %%
reason=[None]

# %%
# # SQLAlchemy base and engine
# Base = declarative_base()
# # Define the Properties table model
# class propertyintrests(Base):
#     __tablename__ = "propertyintrests"
#     id = Column(Integer, primary_key=True, autoincrement=True)
#     propertyid=Column(Integer)
#     userid=Column(Integer)
#     status=Column(Boolean)
#     reason=Column(String)
#     paymentid=Column(String)
#     createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
#     updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())

# # Create all tables
# Base.metadata.create_all(engine)
# Session=sessionmaker(bind=engine)
# session=Session()

# %%
# from logging import root
# import random
# data_to_insert=[]

# for i in range(1,10):
#    new_property=propertyintrests(
#     # propertyid=random.randint(1,100),
#     userid=random.randint(1,2),
#     status=random.choice([True,False]),
#     reason=random.choice(reason),
#     paymentid=random.choice(reason),
#     createdAt= datetime.datetime.now(datetime.timezone.utc),
#     updatedAt= datetime.datetime.now(datetime.timezone.utc)
#     )
#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()

# %%
# # SQLAlchemy base and engine
# Base = declarative_base()
# # Define the Properties table model
# class propertylocations(Base):
#     __tablename__ = "propertylocations"
#     id = Column(Integer, primary_key=True, autoincrement=True)
#     address=Column(String)
#     city=Column(String)
#     state=Column(String)
#     neighborhood=Column(String)
#     latitude=Column(DOUBLE_PRECISION)
#     longitude=Column(DOUBLE_PRECISION)
#     propertyid=Column(Integer)
#     createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
#     updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())

# # Create all tables
# Base.metadata.create_all(engine)
# Session=sessionmaker(bind=engine)
# session=Session()

# %%
# address= [
#     "Kalyani Nagar, Pune",
#     "Viman Nagar, Pune",
#     "Hinjewadi, Pune",
#     "Baner, Pune",
#     "Aundh, Pune",
#     "Wagholi, Pune",
#     "Koregaon Park, Pune",
#     "Kothrud, Pune",
#     "Shivaji Nagar, Pune",
#     "Chandni Chowk, Pune",
#     "Camp, Pune",
#     "Pimpri, Pune",
#     "Chinchwad, Pune",
#     "Hadapsar, Pune",
#     "Sinhagad Road, Pune",
#     "Swargate, Pune",
#     "Wakad, Pune",
#     "Talegaon, Pune",
#     "Bhosari, Pune",
#     "Balewadi, Pune",
#     "Gandhi Nagar, Latur",
#     "Shivaji Chowk, Latur",
#     "MIDC, Latur",
#     "Barshi Road, Latur",
#     "Ambajogai Road, Latur",
#     "Udgir Road, Latur",
#     "Ram Nagar, Latur",
#     "Tilak Nagar, Latur",
#     "Ganjgolai, Latur",
#     "Ahmedpur Road, Latur",
#     "Colaba, Mumbai",
#     "Marine Drive, Mumbai",
#     "Dadar, Mumbai",
#     "Bandra, Mumbai",
#     "Andheri, Mumbai",
#     "Borivali, Mumbai",
#     "Malad, Mumbai",
#     "Juhu, Mumbai",
#     "Powai, Mumbai",
#     "Kurla, Mumbai",
#     "Panvel, Navi Mumbai",
#     "Vashi, Navi Mumbai",
#     "Kharghar, Navi Mumbai",
#     "Belapur, Navi Mumbai",
#     "Airoli, Navi Mumbai",
#     "Ghansoli, Navi Mumbai",
#     "Sanpada, Navi Mumbai",
#     "Nerul, Navi Mumbai",
#     "Seawoods, Navi Mumbai",
#     "Kamothe, Navi Mumbai",
#     "Chinchpokli, Mumbai",
#     "Mazgaon, Mumbai",
#     "Grant Road, Mumbai",
#     "Byculla, Mumbai",
#     "Bhandup, Mumbai",
#     "Mulund, Mumbai",
#     "Goregaon, Mumbai",
#     "Virar, Mumbai",
#     "Nala Sopara, Mumbai",
#     "Mira Road, Mumbai",
#     "Chembur, Mumbai",
#     "Thane West, Thane",
#     "Thane East, Thane",
#     "Kasarvadavali, Thane",
#     "Majiwada, Thane",
#     "Manpada, Thane",
#     "Ghodbunder Road, Thane",
#     "Vartak Nagar, Thane",
#     "Hiranandani Estate, Thane",
#     "Kalwa, Thane",
#     "Wagle Estate, Thane",
#     "Satara Road, Satara",
#     "Karad, Satara",
#     "Panchgani, Satara",
#     "Mahabaleshwar, Satara",
#     "Koregaon, Satara",
#     "Phaltan, Satara",
#     "Wai, Satara",
#     "Kudal, Sindhudurg",
#     "Sawantwadi, Sindhudurg",
#     "Malvan, Sindhudurg",
#     "Vengurla, Sindhudurg",
#     "Devgad, Sindhudurg",
#     "Kankavli, Sindhudurg",
#     "Ratnagiri, Ratnagiri",
#     "Chiplun, Ratnagiri",
#     "Dapoli, Ratnagiri",
#     "Khed, Ratnagiri",
#     "Guhagar, Ratnagiri",
#     "Lanja, Ratnagiri",
#     "Mandangad, Ratnagiri",
#     "Rajapur, Ratnagiri",
#     "Kolhapur, Kolhapur",
#     "Ichalkaranji, Kolhapur",
#     "Gadhinglaj, Kolhapur",
#     "Panhala, Kolhapur",
#     "Shiroli, Kolhapur",
#     "Kagal, Kolhapur",
#     "Miraj, Sangli",
#     "Sangliwadi, Sangli",
#     "Kupwad, Sangli",
#     "Vishrambag, Sangli",
#     "Tasgaon, Sangli",
#     "Palus, Sangli",
#     "Islampur, Sangli",
#     "Vita, Sangli",
#     "Nanded City, Pune",
#     "Shirdi, Ahmednagar",
#     "Sangamner, Ahmednagar",
#     "Kopargaon, Ahmednagar",
#     "Pathardi, Ahmednagar",
#     "Shrigonda, Ahmednagar",
#     "Parner, Ahmednagar",
#     "Rahata, Ahmednagar",
#     "Beed, Beed",
#     "Ambejogai, Beed",
#     "Parli, Beed",
#     "Karanja, Washim",
#     "Malegaon, Nashik",
#     "Deolali, Nashik",
#     "Kalwan, Nashik",
#     "Yeola, Nashik",
#     "Manmad, Nashik",
#     "Niphad, Nashik",
#     "Sinnar, Nashik",
#     "Peth, Nashik",
#     "Lasalgaon, Nashik",
#     "Jalgaon, Jalgaon",
#     "Chalisgaon, Jalgaon",
#     "Amalner, Jalgaon",
#     "Pachora, Jalgaon",
#     "Bhusawal, Jalgaon",
#     "Erandol, Jalgaon",
#     "Parola, Jalgaon",
#     "Chopda, Jalgaon",
#     "Dhule, Dhule",
#     "Shirpur, Dhule",
#     "Sakri, Dhule",
#     "Nandurbar, Nandurbar",
#     "Navapur, Nandurbar",
#     "Shahada, Nandurbar",
#     "Buldhana, Buldhana",
#     "Chikhli, Buldhana",
#     "Malkapur, Buldhana",
#     "Shegaon, Buldhana",
#     "Khamgaon, Buldhana",
#     "Nagpur, Nagpur",
#     "Hingna, Nagpur",
#     "Katol, Nagpur",
#     "Kamthi, Nagpur",
#     "Wardha, Wardha",
#     "Hinganghat, Wardha",
#     "Yavatmal, Yavatmal",
#     "Pusad, Yavatmal",
#     "Washim, Washim",
#     "Akola, Akola",
#     "Murtizapur, Akola",
#     "Amravati, Amravati",
#     "Chandrapur, Chandrapur",
#     "Ballarpur, Chandrapur",
#     "Gadchiroli, Gadchiroli",
#     "Bhandara, Bhandara",
#     "Gondia, Gondia"
# ]

# city= [
#     "Pune", "Mumbai", "Thane", "Navi Mumbai", "Aurangabad", "Nashik",
#     "Nagpur", "Kolhapur", "Solapur", "Satara", "Sangli", "Lonavala"
# ]
# state = ["Maharashtra"]
# neighborhood=[None]
# latitude = [
#     18.5397, 18.5642, 18.5970, 18.5583, 18.5523, 18.5863, 18.5378, 18.5074,
#     18.5298, 18.4908, 18.5169, 18.6458, 18.6446, 18.6155, 18.6841, 18.5673,
#     18.6163, 18.5947, 18.5217, 18.5565, 18.6429, 18.4531, 18.5080, 18.7043,
#     18.5309, 19.0795, 19.1515, 18.9574, 18.9373, 18.9242, 18.9345, 18.8523,
#     18.8529, 19.0649, 19.4313, 19.3184, 19.0532, 19.1295, 19.2639, 19.2183,
#     19.1519, 19.2009, 19.1975, 19.2074, 19.0976, 19.0506, 19.0434, 19.0595,
#     19.0295, 19.0749, 18.9749, 18.9478, 19.1008, 18.9745, 18.8537, 19.0598,
#     19.0493, 19.0142, 19.3125, 19.3361, 19.4852, 19.6437, 19.5527, 19.5268,
#     19.6140, 19.6580, 19.7686, 19.8010, 19.7790, 19.7156, 19.7231, 19.7768,
#     19.8053, 19.8320, 19.8673, 19.9098, 19.9512, 19.9958, 20.0483, 20.0260,
#     20.0161, 20.0120, 20.0429, 20.0712, 20.1015, 20.1169, 20.1070, 20.1389,
#     20.1571, 20.1892, 20.1559, 20.1714, 20.1241, 20.1087, 20.1356, 20.1146,
#     20.1097, 20.1782, 20.1867, 20.1513, 20.1525, 20.1684, 20.1490, 20.1770,
#     20.1412, 20.1313, 20.1158, 20.1062, 20.0823, 20.0757, 20.0948, 20.0875,
#     20.1230, 20.1151, 20.0815, 20.1050, 20.1164, 20.0867, 20.0950, 20.0898,
#     20.0832, 20.0866, 20.0921, 20.0968, 20.1229, 20.1101, 20.0960, 20.0783,
#     20.1103, 20.0992, 20.1225, 20.1085, 20.0861, 20.0962, 20.1119, 20.0984,
#     20.0847, 20.0719, 20.1013, 20.0899, 20.0975, 20.0864, 20.0716, 20.0734,
#     20.0830, 20.0918, 20.0853, 20.1067, 20.1051, 20.1018, 20.1079, 20.1183,
#     20.0979, 20.0923, 20.1023, 20.1004, 20.1127, 20.1198, 20.1072, 20.1152,
#     20.1048, 20.0961, 20.0838, 20.0912, 20.0794, 20.0971, 20.0883, 20.1068
# ]
# longitude = [
#     73.9125, 73.9184, 73.7802, 73.8010, 73.8177, 73.9271, 73.9233, 73.8082,
#     73.8301, 73.8587, 73.8794, 73.8734, 73.8395, 73.8811, 73.9286, 73.7963,
#     73.9137, 73.9185, 73.8030, 73.9183, 73.8884, 73.7642, 73.8157, 73.8514,
#     73.7911, 73.7724, 74.3244, 74.2749, 74.2311, 74.1345, 74.1052, 74.0671,
#     74.0300, 73.9677, 74.0779, 74.0736, 73.9373, 73.7997, 73.8303, 73.8699,
#     73.8874, 73.9317, 73.9992, 74.1062, 74.1844, 74.2174, 74.2040, 74.1867,
#     74.1707, 74.2674, 74.3171, 74.2493, 74.1632, 74.0893, 74.0141, 73.9416,
#     73.8589, 73.8040, 73.7367, 73.7580, 73.8047, 73.7684, 73.7095, 73.7108,
#     73.7331, 73.7309, 73.7255, 73.6797, 73.6040, 73.5972, 73.5591, 73.5834,
#     73.5730, 73.5324, 73.5368, 73.5180, 73.4671, 73.4679, 73.4712, 73.4930,
#     73.5208, 73.4964, 73.4855, 73.4893, 73.5130, 73.5103, 73.5395, 73.5343,
#     73.5258, 73.5251, 73.5165, 73.4859, 73.4638, 73.4670, 73.4515, 73.4401,
#     73.4319, 73.4043, 73.3802, 73.3700, 73.3549, 73.3380, 73.3140, 73.2991,
#     73.2815, 73.2652, 73.2555, 73.2433, 73.2357, 73.2275, 73.2264, 73.2201,
#     73.2114, 73.1980, 73.1757, 73.1576, 73.1301, 73.1084, 73.0901, 73.0844,
#     73.0868, 73.0650, 73.0575, 73.0583, 73.0585, 73.0427, 73.0224, 73.0152,
#     73.0027, 72.9817, 72.9812, 72.9643, 72.9601, 72.9542, 72.9538, 72.9277,
#     72.9273, 72.9068, 72.9035, 72.8843, 72.8800, 72.8699, 72.8590, 72.8484,
#     72.8329, 72.8194, 72.8092, 72.8009, 72.7865, 72.7769, 72.7587, 72.7544
# ]

# %%
# from logging import root
# import random
# data_to_insert=[]

# for i in range(1,10):
#    new_property=propertylocations(
#     address=random.choice(address),
#     city=random.choice(city),
#     state=random.choice(state),
#     neighborhood=random.choice(neighborhood),
#     latitude=random.choice(latitude),
#     longitude=random.choice(longitude),
#     # propertyid=random.randint(1,100),
#     createdAt= datetime.datetime.now(datetime.timezone.utc),
#     updatedAt= datetime.datetime.now(datetime.timezone.utc)
#     )

#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()

# %%
# import random

# def generate_random_image_paths(filenames, base_path="./nodeimages/property/"):
#     num_images = random.randint(1, 20)  # Randomly select number of images between 1 and the length of filenames
#     random_files = random.sample(filenames, num_images)  # Select the random files
#     return [f"{base_path}{filename}" for filename in random_files]

# # Example usage:
# filenames = [
# "20230828T055332813Z_9qcw8f.jpeg","20230828T055332814Z_mtjvu.jpeg",
# "20230828T060528188Z_ob04x5.jpeg","20230828T060528189Z_zinfv.jpeg","20230828T060528191Z_00b49r.jpeg","20230828T060528192Z_nfg8dv.jpeg","20230828T060528194Z_xkjb1k.jpeg",
# "20230828T060528195Z_mggvjv.jpeg","20230828T060528195Z_sik5fe.jpeg",
# "20230828T063856010Z_qfciz.jpeg","20230828T063856012Z_n0gwfp.jpeg",
# "20230828T063856013Z_mjvb96a.jpeg","20230828T063856014Z_cv7pekb.jpeg",
# "20230828T063856015Z_bdhsrc.jpeg","20230828T063856016Z_d8e9y5.jpeg",
# "20230828T063856017Z_8y8hkb.jpeg","20230828T074122940Z_mm1kuc.jpeg",
# "20230828T074122942Z_hjpoh.jpeg","20230828T074122942Z_ui83j.jpeg",
# "20230828T074122943Z_zsk7fs.jpeg",
# "20230828T074122944Z_041o2i.jpeg","20230828T074122945Z_uo4i27.jpeg",
# "20230828T074122946Z_vh21dd.jpeg","20230828T100610558Z_cpisu6.jpeg",
# "20230828T100610559Z_tjfiu9.jpeg","20230828T100610560Z_ho8ihp.jpeg",
# "20230828T100610560Z_ookmd1r.jpeg",
# "20230828T100610560Z_t2raw.jpeg","20230828T111433408Z_8tmhi7s.jpeg",
# "20230828T111433410Z_ducr49.jpeg","20230828T111433412Z_2989sm.jpeg",
# "20230828T111433413Z_uf8bx.jpeg","20230828T111433414Z_ddhwl.jpeg",
# "20230828T111433415Z_us7nnj.jpeg","20230828T111433416Z_ka6d6c.jpeg",
# "20230828T122819159Z_7tzvha.jpeg","20230828T122819160Z_ucz7sa.jpeg",
# "20230828T122819161Z_i0wq7es.jpeg","20230828T122819162Z_d7hvgg.jpeg",
# "20230828T122819163Z_hi9mjq.jpeg","20240411T104522425Z_vbrqu.jpeg",
# "20240411T104522426Z_6rsgxb.jpeg","20240411T104522428Z_18hjy.jpeg",
# "20240412T072748580Z_64ia8.jpeg","20240412T072748582Z_mzt4fr.jpeg",
# "20240412T072748583Z_evt56.jpeg","20240412T072748584Z_ev6wfp.jpeg",
# "20240412T072748602Z_sgnpu6.jpeg","20240412T072748603Z_irriy.jpeg",
# "20240412T115148141Z_iitdu.jpeg","20240412T115148143Z_jmdakw.jpeg",
# "20240412T115148144Z_7df8pd.jpeg","20240412T120034140Z_gif8er.jpeg",
# "20240412T120034141Z_7744rk.jpeg","20240412T120034142Z_30xf5k.jpeg",
# "20240412T120034143Z_ojnujn.jpeg","20240415T051712104Z_3m2g6.jpeg",
# "20240415T051712105Z_odhtrh.jpeg","20240415T051712105Z_zg63ad.jpeg",
# "20240415T051712106Z_1ffm4m.jpeg","20240415T062334534Z_ukuz48.jpeg",
# "20240415T062334535Z_0vai57.jpeg","20240415T062334537Z_aefq9b.jpeg",
# "20240415T062334537Z_jlxbuu.jpeg","20240415T062334537Z_kqmfsk.jpeg",
# "20240415T064529182Z_d5gigg.jpeg","20240415T064529183Z_030d4i.jpeg",
# "20240415T064529185Z_qi3vr.jpeg","20240415T064529188Z_tjb77p.jpeg",
# "20240415T074730712Z_gd0glc.jpeg","20240415T074730714Z_10ugh9.jpeg",
# "20240415T074730715Z_28w0gp.jpeg","20240415T074730715Z_9qqyt.jpeg",
# "20240416T050904361Z_i9yino.jpeg","20240416T050904362Z_frmf6.jpeg",
# "20240416T050904363Z_2xcu1s.jpeg","20240416T050904363Z_n0t0ls.jpeg",
# "20240416T050904364Z_zdthy.jpeg","20240502T064009503Z_5fvjnj.jpeg",
# "20240502T064009514Z_edu7vg.jpeg","20250116T114315745Z_qxri2d.jpeg",
# "20250116T114317002Z_lgbbeg.jpeg","20250116T114317012Z_7rrfym.jpeg",
# "20250116T114331052Z_fwft5l.jpeg","20250116T114331063Z_gbm9uq.jpeg",
# "20250116T114342120Z_npfj6.jpeg","20250116T114342131Z_nw8e8u.jpeg",
# "20250116T114343555Z_icpvo.jpeg","20250116T114343561Z_f63yy.jpeg",
# "20250116T114343726Z_dtttb.jpeg","20250116T114343731Z_103air.jpeg",
# "20250116T114355011Z_ksgv5p.jpeg","20250116T114355019Z_a5tey.jpeg",
# "20250116T114355357Z_x1h4gc.jpeg","20250116T114355362Z_wa8v4h.jpeg",
# "20250116T114355999Z_d896v.jpeg","20250116T114356005Z_1b9qhv.jpeg",
# "20250116T114356956Z_g3qv73.jpeg",
# "20250116T114356962Z_piz0k.jpeg",
# "20250116T114412825Z_igppqa.jpeg",
# "20250116T114412835Z_vopp4.jpeg",
# "20250116T114413748Z_zutjku.jpeg",
# "20250116T114413754Z_40awsk.jpeg",
# "20250116T114414810Z_py3olb.jpeg",
# "20250116T114414816Z_ycf19e.jpeg",
# "20250116T114415106Z_xfvzd.jpeg",
# "20250116T114415114Z_usi6b.jpeg",
# "20250116T114415771Z_mu6yfi.jpeg",
# "20250116T114415777Z_bdngmg.jpeg",
# "20250116T114427194Z_oer26f.jpeg",
# "20250116T114427201Z_t9h69.jpeg",
# "20250116T115229567Z_11vvj9.jpeg",
# "20250121T072624380Z_hyhshh.jpeg",
# "20250121T072624381Z_2ajkdb.png",
# "20250121T072624381Z_6ukk5.jpeg",
# "20250121T072624381Z_hq3ynb.jpeg",
# "20250121T072624382Z_wd4zxh.jpeg"

# ]

# # Get a random number of random image paths
# property_data=[]
# for i in range(10):
#   image_paths = generate_random_image_paths(filenames)
#   property_data.append(image_paths)

# %%
# import random

# def generate_random_image_paths(filenames, base_path="./nodeimages/propertyfloors/"):
#     num_images = random.randint(1, 20)  # Randomly select number of images between 1 and the length of filenames
#     random_files = random.sample(filenames, num_images)  # Select the random files
#     return [f"{base_path}{filename}" for filename in random_files]

# filenames = [
#     "20230828T063856018Z_h4e7qr.jpeg", "20240503T110939763Z_0wrhqi.jpeg", "20250116T114356967Z_i993gg.jpeg",
#     "20230828T063856018Z_owsfxg.jpeg", "20240530T042136183Z_wwel3.jpeg", "20250116T114356975Z_mkok1a.jpeg",
#     "20230828T074122947Z_95rqy.jpeg", "20240624T093743810Z_oxr8k.jpeg", "20250116T114412843Z_10chjf.jpeg",
#     "20230828T074122947Z_q2ecw.jpeg", "20240624T093743812Z_oxcied.png", "20250116T114412870Z_4fxd1.jpeg",
#     "20230828T100610560Z_dlijr5.jpeg", "20240628T120221209Z_bvlvry.jpeg", "20250116T114413759Z_u74llp.jpeg",
#     "20230828T100610560Z_ynk4jh.png", "20240628T120221210Z_6p6av.png", "20250116T114413767Z_yozg79.jpeg",
#     "20230828T111433417Z_dwsr3.jpeg", "20240808T120806249Z_j559qr.jpeg", "20250116T114414821Z_ng6mx.jpeg",
#     "20230828T111433417Z_sdwd2n.jpeg", "20240808T120806256Z_4h63ti.jpeg", "20250116T114414830Z_zmgtt.jpeg",
#     "20230828T122819165Z_6hbe8.jpeg", "20240808T120806256Z_x6ipai.jpeg", "20250116T114415122Z_sy5vtu.jpeg",
#     "20230828T122819166Z_me3ooc.jpeg", "20240812T094629209Z_hfjfx.jpeg", "20250116T114415135Z_r3o2qh.jpeg",
#     "20230829T064450707Z_wwiwr.jpeg", "20240812T094636773Z_lmaunl.jpeg", "20250116T114415782Z_1bklu.jpeg",
#     "20230829T065910528Z_y959sm.jpeg", "20240819T085547547Z_rylj3p.jpeg", "20250116T114415789Z_8645jk.jpeg",
#     "20230829T065910529Z_zfqo2a.jpeg", "20240819T103249279Z_a3sn8m.png", "20250116T114427209Z_nx556c.jpeg",
#     "20230829T102417196Z_zfyyj.jpeg", "20240819T111929276Z_vwiwr.png", "20250116T114427237Z_6aazg.jpeg",
#     "20230829T102417197Z_9jzgxn.jpeg", "20240819T112042089Z_u9j4qk.png", "20250116T115229578Z_ylz8e.jpeg",
#     "20230831T113518997Z_orh4xj.jpeg", "20240819T112336402Z_fafb1d.png", "20250120T044159289Z_8348qe.jpeg",
#     "20230831T113518998Z_dtfo1e.png", "20240820T091627346Z_7xsmpu.jpeg", "20250121T072624382Z_likhad.jpeg",
#     "20230831T113555858Z_2wvyar.png", "20240821T052603076Z_kp6lq.png", "20250121T072624382Z_u1l2bi.jpeg",
#     "20230831T113555858Z_brb2oo.jpeg", "20240822T110355741Z_56dhye.jpeg", "20250121T072624383Z_ga9ed.jpeg",
#     "20230831T121542338Z_hws4l6.jpeg", "20240822T110355741Z_grt11.jpeg"
# ]

# # Get a random number of random image paths
# property_floors=[]
# for i in range(10):
#   image_paths = generate_random_image_paths(filenames)
#   property_floors.append(image_paths)

# %%
# import random

# def generate_random_image_paths(filenames, base_path="./nodeimages/unitplan/"):
#     num_images= random.randint(1, 20)  # Randomly select number of images between 1 and the length of filenames
#     # num_images = random.randint(1,numdata)  # Randomly select number of images between 1 and the length of filenames
#     random_files = random.sample(filenames, num_images)  # Select the random files
#     print(random_files)

#     return [f"{base_path}{filename}" for filename in random_files]
# filenames = [
#     "20240402T065637380Z_p7ezsv.jpeg", "20240822T110355742Z_2wir.jpeg", "20250116T114343594Z_9n5wsb.jpeg",
#     "20250116T114412904Z_wjoutm.jpeg", "20240402T094010563Z_vl7lni.jpeg", "20240822T110355742Z_l7194t.jpeg",
#     "20250116T114343601Z_yob5k1.jpeg", "20250116T114413773Z_4xwgv5.jpeg", "20240403T123932114Z_b6egdx.jpeg",
#     "20240822T110356874Z_8s8nyd.jpeg", "20250116T114343610Z_jqu53e.jpeg", "20250116T114413780Z_5owpp.jpeg",
#     "20240404T113653538Z_b0a3af.jpeg", "20240822T110356874Z_zm3xw.jpeg", "20250116T114343616Z_o5t1bk.jpeg",
#     "20250116T114413787Z_x1ogkk.jpeg", "20240410T064211177Z_3saaan.jpeg", "20240826T081431534Z_7q3tsg.jpeg",
#     "20250116T114343755Z_m12z0o.jpeg", "20250116T114413796Z_jq2u9o.jpeg", "20240411T093900134Z_sqjxor.jpeg",
#     "20240921T093600077Z_8fsm2l.jpeg", "20250116T114343763Z_ke1bi.jpeg", "20250116T114413801Z_fl1gbp.jpeg",
#     "20240411T104522430Z_atzad.jpeg", "20240921T093600078Z_a4xhap.jpeg", "20250116T114343770Z_y42om.jpeg",
#     "20250116T114414836Z_3nr8f.jpeg", "20240412T072748604Z_ayo1f.jpeg", "20241025T050935838Z_3515ak.png",
#     "20250116T114343779Z_rrovge.jpeg", "20250116T114414843Z_wcq67.jpeg", "20240412T115148145Z_hvo16.jpeg",
#     "20241104T080523792Z_snvz8.jpeg", "20250116T114343784Z_tx36x.jpeg", "20250116T114414849Z_peytoo.jpeg",
#     "20240412T120034143Z_cb2b1t.jpeg", "20241104T080618965Z_b1t2pq.jpeg", "20250116T114355041Z_fid89e.jpeg",
#     "20250116T114414860Z_rx2uv.jpeg", "20240415T051712109Z_iyba8i.jpeg", "20241104T094858830Z_l5w5o.png",
#     "20250116T114355048Z_2dcxf8.jpeg", "20250116T114414866Z_ipcsz9.jpeg", "20240415T062334540Z_7xenwj.jpeg",
#     "20241226T104129410Z_juw4hd.jpeg", "20250116T114355054Z_5m6kgd.jpeg", "20250116T114415144Z_0nczoq.jpeg",
#     "20240415T064529190Z_8avaq.jpeg", "20250102T121318705Z_jqtzf.jpeg", "20250116T114355064Z_l7lzf.jpeg",
#     "20250116T114415154Z_7l3k4.jpeg", "20240415T074730717Z_wab73g.jpeg", "20250116T114355072Z_58o6kj.jpeg"
# ]


# # Get a random number of random image paths
# # image_paths = generate_random_ima.ge_paths(filenames)
# property_unitplans=[]
# for i in range(10):
#   hllo=generate_random_image_paths(filenames)
#   property_unitplans.append(hllo)
# Out:
# ['20250116T114343610Z_jqu53e.jpeg', '20250116T114343763Z_ke1bi.jpeg', '20250116T114355072Z_58o6kj.jpeg', '20250116T114413773Z_4xwgv5.jpeg', '20250116T114414866Z_ipcsz9.jpeg', '20240412T115148145Z_hvo16.jpeg', '20250116T114343779Z_rrovge.jpeg', '20240415T062334540Z_7xenwj.jpeg', '20240410T064211177Z_3saaan.jpeg', '20240411T093900134Z_sqjxor.jpeg', '20250116T114413796Z_jq2u9o.jpeg', '20250116T114413801Z_fl1gbp.jpeg', '20241104T080523792Z_snvz8.jpeg', '20240402T065637380Z_p7ezsv.jpeg', '20250116T114343755Z_m12z0o.jpeg', '20240822T110355742Z_l7194t.jpeg', '20250116T114415154Z_7l3k4.jpeg']
# ...

# %%
# # SQLAlchemy base and engine
# Base = declarative_base()
# # Define the Properties table model
# class propertymedia(Base):
#     __tablename__ = "propertymedia"
#     id = Column(Integer, primary_key=True, autoincrement=True)
#     images=Column(JSON)
#     floors=Column(JSON)
#     unitplans=Column(JSON)
#     videoid=Column(String)
#     videotype=Column(String)
#     virtualtour=Column(String)
#     propertyid=Column(Integer)
#     createdAt = Column(TIMESTAMP(timezone=True), server_default=func.now())
#     updatedAt = Column(TIMESTAMP(timezone=True), server_default=func.now(), onupdate=func.now())
#     embedding=Column(String)

# # Create all tables
# Base.metadata.create_all(engine)
# Session=sessionmaker(bind=engine)
# session=Session()

# %%
videoid=[None]
videotype=[None]
virtualtour=[None]
embedding=[None]

# %%
# from logging import root
# import random
# data_to_insert=[]

# for i in range(1,10):
#    new_property=propertymedia(
#     images=random.choice(property_data),
#     floors=random.choice(property_floors),
#     unitplans=random.choice(property_unitplans),
#     videoid=random.choice(videoid),
#     videotype=random.choice(videotype),
#     virtualtour=random.choice(virtualtour),
#     # propertyid=random.randint(1,100),
#     createdAt= datetime.datetime.now(datetime.timezone.utc),
#     updatedAt= datetime.datetime.now(datetime.timezone.utc),
#     embedding=random.choice(embedding)
#     )

#    data_to_insert.append(new_property)

# session.bulk_save_objects(data_to_insert)
# session.commit()
